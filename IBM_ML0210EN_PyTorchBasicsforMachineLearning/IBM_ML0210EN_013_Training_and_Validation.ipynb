# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):

    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]

            #outliers
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass

    # Getter
    def __getitem__(self, index):
        return self.x[index], self.y[index]

    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):

    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)

    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):

    # iterate through different learning rates
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()

        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[1.2407163]
#  [1.2076182]
#  [1.1745201]]
# 1 [[5.954484 ]
#  [5.8374567]
#  [5.7204294]]
# 2 [[6.5800476]
#  [6.4464483]
#  [6.312848 ]]
# 3 [[14.457824]
#  [14.023871]
#  [13.589917]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

for x, y in trainloader:
    print("yhat= ", model(x),"y", y)
# Out:
# yhat=  tensor([[14.4578]], grad_fn=<AddmmBackward0>) y tensor([[0.]])
# yhat=  tensor([[14.0239]], grad_fn=<AddmmBackward0>) y tensor([[9.7296]])
# yhat=  tensor([[13.5899]], grad_fn=<AddmmBackward0>) y tensor([[9.3976]])
# yhat=  tensor([[13.1560]], grad_fn=<AddmmBackward0>) y tensor([[9.0710]])
# yhat=  tensor([[12.7220]], grad_fn=<AddmmBackward0>) y tensor([[8.5799]])
# yhat=  tensor([[12.2881]], grad_fn=<AddmmBackward0>) y tensor([[8.5110]])
# yhat=  tensor([[11.8541]], grad_fn=<AddmmBackward0>) y tensor([[8.2640]])
# yhat=  tensor([[11.4201]], grad_fn=<AddmmBackward0>) y tensor([[7.8036]])
# yhat=  tensor([[10.9862]], grad_fn=<AddmmBackward0>) y tensor([[7.5375]])
# yhat=  tensor([[10.5522]], grad_fn=<AddmmBackward0>) y tensor([[7.2928]])
# yhat=  tensor([[10.1183]], grad_fn=<AddmmBackward0>) y tensor([[7.0244]])
# yhat=  tensor([[9.6843]], grad_fn=<AddmmBackward0>) y tensor([[6.6991]])
# yhat=  tensor([[9.2504]], grad_fn=<AddmmBackward0>) y tensor([[6.2984]])
# yhat=  tensor([[8.8164]], grad_fn=<AddmmBackward0>) y tensor([[6.0646]])
# yhat=  tensor([[8.3825]], grad_fn=<AddmmBackward0>) y tensor([[5.7268]])
# yhat=  tensor([[7.9485]], grad_fn=<AddmmBackward0>) y tensor([[5.3856]])
# yhat=  tensor([[7.5146]], grad_fn=<AddmmBackward0>) y tensor([[5.1002]])
# yhat=  tensor([[7.0806]], grad_fn=<AddmmBackward0>) y tensor([[5.0056]])
# yhat=  tensor([[6.6467]], grad_fn=<AddmmBackward0>) y tensor([[4.6653]])
# yhat=  tensor([[6.2127]], grad_fn=<AddmmBackward0>) y tensor([[4.2441]])
# yhat=  tensor([[5.7788]], grad_fn=<AddmmBackward0>) y tensor([[3.9432]])
# yhat=  tensor([[5.3448]], grad_fn=<AddmmBackward0>) y tensor([[3.7243]])
# yhat=  tensor([[4.9108]], grad_fn=<AddmmBackward0>) y tensor([[3.4404]])
# yhat=  tensor([[4.4769]], grad_fn=<AddmmBackward0>) y tensor([[3.1303]])
# yhat=  tensor([[4.0429]], grad_fn=<AddmmBackward0>) y tensor([[2.7923]])
# yhat=  tensor([[3.6090]], grad_fn=<AddmmBackward0>) y tensor([[2.3373]])
# yhat=  tensor([[3.1750]], grad_fn=<AddmmBackward0>) y tensor([[2.0915]])
# yhat=  tensor([[2.7411]], grad_fn=<AddmmBackward0>) y tensor([[2.1040]])
# yhat=  tensor([[2.3071]], grad_fn=<AddmmBackward0>) y tensor([[1.6563]])
# yhat=  tensor([[1.8732]], grad_fn=<AddmmBackward0>) y tensor([[1.2892]])
# yhat=  tensor([[1.4392]], grad_fn=<AddmmBackward0>) y tensor([[1.0599]])
# yhat=  tensor([[1.0053]], grad_fn=<AddmmBackward0>) y tensor([[0.6554]])
# yhat=  tensor([[0.5713]], grad_fn=<AddmmBackward0>) y tensor([[0.5454]])
# yhat=  tensor([[0.1374]], grad_fn=<AddmmBackward0>) y tensor([[0.1625]])
# yhat=  tensor([[-0.2966]], grad_fn=<AddmmBackward0>) y tensor([[-0.1493]])
# yhat=  tensor([[-0.7306]], grad_fn=<AddmmBackward0>) y tensor([[-0.5137]])
# yhat=  tensor([[-1.1645]], grad_fn=<AddmmBackward0>) y tensor([[-0.5686]])
# yhat=  tensor([[-1.5985]], grad_fn=<AddmmBackward0>) y tensor([[-1.0172]])
# yhat=  tensor([[-2.0324]], grad_fn=<AddmmBackward0>) y tensor([[-1.3469]])
# yhat=  tensor([[-2.4664]], grad_fn=<AddmmBackward0>) y tensor([[-1.8302]])
# yhat=  tensor([[-2.9003]], grad_fn=<AddmmBackward0>) y tensor([[-1.9844]])
# yhat=  tensor([[-3.3343]], grad_fn=<AddmmBackward0>) y tensor([[-2.2955]])
# yhat=  tensor([[-3.7682]], grad_fn=<AddmmBackward0>) y tensor([[-2.5175]])
# yhat=  tensor([[-4.2022]], grad_fn=<AddmmBackward0>) y tensor([[-2.8138]])
# yhat=  tensor([[-4.6361]], grad_fn=<AddmmBackward0>) y tensor([[-3.3099]])
# yhat=  tensor([[-5.0701]], grad_fn=<AddmmBackward0>) y tensor([[-3.4542]])
# yhat=  tensor([[-5.5040]], grad_fn=<AddmmBackward0>) y tensor([[-3.7063]])
# yhat=  tensor([[-5.9380]], grad_fn=<AddmmBackward0>) y tensor([[-4.0632]])
# yhat=  tensor([[-6.3719]], grad_fn=<AddmmBackward0>) y tensor([[-4.4588]])
# yhat=  tensor([[-6.8059]], grad_fn=<AddmmBackward0>) y tensor([[-4.7931]])
# yhat=  tensor([[-7.2399]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-7.6738]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.1078]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.5417]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.9757]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-9.4096]], grad_fn=<AddmmBackward0>) y tensor([[-6.5127]])
# yhat=  tensor([[-9.8436]], grad_fn=<AddmmBackward0>) y tensor([[-6.9320]])
# yhat=  tensor([[-10.2775]], grad_fn=<AddmmBackward0>) y tensor([[-6.9899]])
# yhat=  tensor([[-10.7115]], grad_fn=<AddmmBackward0>) y tensor([[-7.2582]])
# yhat=  tensor([[-11.1454]], grad_fn=<AddmmBackward0>) y tensor([[-7.7310]])
